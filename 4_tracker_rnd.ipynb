# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
dir = 'D:/bme/rnd/dists.txt'

X1 = pd.read_csv(dir, header=None)

# %%
X1.hist(bins=50)
plt.xlabel('Average Manhattan Distance to Q')
plt.ylabel('Frequency')
plt.title('Easy Trial')
# Out:
# Text(0.5, 1.0, 'Easy Trial')

# %%
dir = 'D:/bme/rnd/dists2.txt'

X2 = pd.read_csv(dir, header=None)

# %%
X2.hist(bins=50)
plt.xlabel('Average Manhattan Distance to Q')
plt.ylabel('Frequency')
plt.title('Hard Trial')
# Out:
# Text(0.5, 1.0, 'Hard Trial')
